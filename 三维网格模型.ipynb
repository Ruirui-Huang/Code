# %%
# %matplotlib notebook
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
from matplotlib import cm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import LinearLocator
from matplotlib.ticker import FuncFormatter

# %%
path = r'D:\Matlab\Data\test.dat'
data = pd.read_table(path, sep = '\t', header=None, engine='python')

# %%
model = np.zeros((32, 32, 16))
for i in range(len(data)):
    index = data.iloc[i]
    x = index[0] - 1
    y = index[1] - 1
    z = index[2] - 1
    model[x][y][z] = 1
model = model > 0

fig = plt.figure(figsize = (8, 4))
ax = fig.gca(projection='3d')
ax.voxels(model, facecolors='red', edgecolor='w', linewidth=0.5)


plt.xticks(np.arange(0, 33, 1), ('0', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '160', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '320', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '480', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '640'))
ax.set_xlabel('L(m)')
plt.yticks(np.arange(0, 33, 1), ('0', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '160', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '320', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '480', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '640'))
ax.set_ylabel('W(m)')
ax.set_zticks(np.arange(0, 17, 1))
ax.set_zticklabels(['-320', ' ', ' ', ' ', '-240 ', ' ', ' ', ' ', '-160', ' ', ' ', ' ', ' -80', ' ', ' ', ' ', '0'])
ax.set_zlabel('H(m)')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
fig = plt.figure(figsize = (8, 4))
import matplotlib as mpl
 
mpl.rcParams['legend.fontsize'] = 10
ax = fig.gca(projection='3d')

x = []
y = []
z = []
for i in range(len(data)):
    index = data.iloc[i]
    x.append(index[0])
    y.append(index[1])
    z.append(index[2])
ax.scatter(x, y, z, c='r', s=5)
ax.plot(x, y, z, linewidth=1, label='Random Walk')


# ax.plot_surface(x, y, z, cmap='rainbow')

plt.xticks(np.arange(0, 33, 1), ('0', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '160', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '320', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '480', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '640'))
ax.set_xlabel('L(m)')
plt.yticks(np.arange(0, 33, 1), ('0', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '160', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '320', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '480', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '640'))
ax.set_ylabel('W(m)')
ax.set_zticks(np.arange(0, 17, 1))
ax.set_zticklabels(['-320', ' ', ' ', ' ', '-240 ', ' ', ' ', ' ', '-160', ' ', ' ', ' ', ' -80', ' ', ' ', ' ', '0'])
ax.set_zlabel('H(m)')

# ax.grid(False)
ax.legend() 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
L, W, H = np.indices((32, 32, 16))

# def midpoints(x):
#     sl = ()
#     for i in range(x.ndim):
#         x = (x[sl + np.index_exp[:-1]] + x[sl + np.index_exp[1:]])/2.0
#         sl += np.index_exp[:]
#     return x

# L = midpoints(L)
# W = midpoints(W)
# H = midpoints(H)

# sphere = (L - 16)**2 + (W - 16)**2 + (H - 8)**2 < 5**2
sphere = np.abs(L-16) + np.abs(W-16) + np.abs(H-8) <  8
# sphere = (L < 20) & (L > 12) & (W < 20) & (W > 12) & (H < 16) & (H > 8)


fig = plt.figure(figsize = (8, 4))
ax = fig.gca(projection='3d')
# ax.voxels(sphere, facecolors='r', edgecolors='w', linewidth=0.5)
ax.voxels(sphere, facecolors='r', edgecolors='w', linewidth=0.5)

plt.xticks(np.arange(0, 33, 1), ('0', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '160', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '320', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '480', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '640'))
ax.set_xlabel('L(m)')
plt.yticks(np.arange(0, 33, 1), ('0', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '160', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '320', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '480', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '640'))
ax.set_ylabel('W(m)')
ax.set_zticks(np.arange(0, 17, 1))
ax.set_zticklabels(['-320', ' ', ' ', ' ', '-240 ', ' ', ' ', ' ', '-160', ' ', ' ', ' ', ' -80', ' ', ' ', ' ', '0'])
ax.set_zlabel('H(m)')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
